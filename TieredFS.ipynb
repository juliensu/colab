# %% [markdown]
# <a href="https://colab.research.google.com/github/juliensu/colab/blob/main/TieredFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpy
# Out:
# Requirement already satisfied: simpy in /usr/local/lib/python3.11/dist-packages (4.1.1)

# %%
import simpy
import random
import time # Importing the time module
import collections # Import collection for deque

class StorageTier:
    def __init__(self, env, name, capacity, bandwidth, latency, lower_tier=None):
        self.env = env
        self.name = name
        self.capacity = capacity
        self.utilization = 0  # Current used space
        self.bandwidth = bandwidth  # Read/write speed (MB/s)
        self.latency = latency  # Read/write latency (ms)
        self.lower_tier = lower_tier  # Link to lower storage tier
        self.queue = simpy.Store(env)  # Queue to accept I/O requests
        self.process = env.process(self.run())  # Start processing requests
        self.data_blocks = {}  # Initialize data_blocks as a dictionary

    def can_store(self, data_size):
        """Check if there is enough space for data"""
        return self.utilization + data_size <= self.capacity

    def run(self):
        """Process I/O requests in the queue"""
        while True:
            operation, data_size, data_id = yield self.queue.get()

            if operation == "read":
                # Check if data_id exists before reading
                if data_id in self.data_blocks:
                    yield self.env.timeout(self.latency / 1000 + data_size / self.bandwidth)
                    print(f"[{self.env.now}] Read #{data_id} {data_size}MB from {self.name}")
                    self.update_last_access(data_id)
                else:
                    print(f"[{self.env.now}] Data #{data_id} not found in {self.name}, checking lower tiers...")
                    # If data not found and lower tier exists, try to read from there
                    if self.lower_tier:
                        yield self.env.process(self.lower_tier.read_from_lower_tier(data_size, data_id))  # Call read_from_lower_tier
                    else:
                        print(f"[{self.env.now}] Data #{data_id} not found in any tier.")


            elif operation == "write":
                if self.can_store(data_size):
                    yield self.env.timeout(self.latency / 1000 + data_size / self.bandwidth)
                    self.utilization += data_size
                    print(f"[{self.env.now}] Wrote #{data_id} {data_size}MB to {self.name}")
                    # Add new data block and set last access time
                    self.add_data_block(data_size, data_id)  # Use data_id here

                else:
                    print(f"[{self.env.now}] {self.name} full, triggering migration")
                    yield self.env.process(self.migrate_data(data_size))

    def read_from_lower_tier(self, data_size, data_id):  # New method
        """Read from lower tier, potentially triggering migration."""
        if data_id in self.data_blocks:
            yield self.env.timeout(self.latency / 1000 + data_size / self.bandwidth)
            print(f"[{self.env.now}] Read #{data_id} {data_size}MB from {self.name} (migrated from lower tier)")
            self.update_last_access(data_id)

            # Migrate to upper tier for faster access (Tier 1 for this example)
            upper_tier = self  # Start from the current tier
            while upper_tier.name != "Tier 1" and upper_tier.lower_tier is not None:
                upper_tier = upper_tier.lower_tier  # Move to the next higher tier


            if upper_tier != self:  # Avoid migrating to the same tier
                # Check if upper tier has enough space, otherwise trigger eviction
                if not upper_tier.can_store(data_size):
                    print(f"[{self.env.now}] {upper_tier.name} is full, triggering eviction to make space...")
                    yield self.env.process(upper_tier.migrate_data(data_size))  # Evict from upper tier

                # Move data from current tier to upper tier
                if self.evict(data_size): #Check if eviction was successful
                    upper_tier.request_io("write", data_size, data_id)
                    print(f"[{self.env.now}] Migrated #{data_id} {data_size}MB from {self.name} to {upper_tier.name}")

        else:
            if self.lower_tier:
                yield self.env.process(self.lower_tier.read_from_lower_tier(data_size, data_id))  # Recursively check lower tiers
            else:
                print(f"[{self.env.now}] Data #{data_id} not found in any tier.")

    def request_io(self, operation, data_size, data_id):
        """Add an I/O request to the queue, including data_id."""
        self.queue.put((operation, data_size, data_id))
        if operation == "write":
            self.add_data_block(data_size, data_id)  # Add data block when writing

    def add_data_block(self, data_size, data_id):
        """Add a new data block and set its last access time."""
        self.data_blocks[data_id] = (data_size, time.time()) # Store size and access time

    def update_last_access(self, data_id):
        """Update the last access time of a data block."""
        if data_id in self.data_blocks:
            self.data_blocks[data_id] = (self.data_blocks[data_id][0], time.time())  # Update access time

    def get_data_blocks(self):
        """Get a list of data blocks and their last access times."""
        return list(self.data_blocks.values())

    def evict(self, block_size):
        """Evict a data block of the given size (LRU)."""

        # Find LRU block with size greater or equal to block_size
        lru_block_id = None
        min_access_time = float('inf')

        for block_id, (size, access_time) in self.data_blocks.items():
            if size >= block_size and access_time < min_access_time:
                min_access_time = access_time
                lru_block_id = block_id

        if lru_block_id is not None:
            self.utilization -= self.data_blocks[lru_block_id][0]
            del self.data_blocks[lru_block_id]
            return True #Eviction successful
        else:
            return False #Failed to find block to evict



    def migrate_data(self, data_size, data_id=None):
        """Move data to the lower tier if full, cascading eviction if necessary."""
        if self.lower_tier:
            # Check if lower tier has enough space
            if self.lower_tier.can_store(data_size):
                # --- Existing eviction and migration logic ---
                data_blocks = self.get_data_blocks()
                data_blocks.sort(key=lambda item: item[1])  # Sort by last access time

                evicted_size = 0
                for block_size, _ in data_blocks:
                    if evicted_size + block_size <= data_size:
                        if self.evict(block_size):  # Check if eviction was successful
                            evicted_size += block_size
                            print(f"[{self.env.now}] Evicted #{data_id} {block_size}MB from {self.name}. Total evicted: {evicted_size}MB")  # Log evicted size
                        else:
                            print(f"[{self.env.now}] Failed to evict a block of size {block_size}MB from {self.name}")  # Log eviction failures
                    else:
                        break

                print(f"[{self.env.now}] Data blocks in {self.name}: {self.data_blocks}")  # Log data blocks before migration

                # Migrate data to the lower tier
                self.lower_tier.request_io("write", evicted_size, data_id)
                print(f"[{self.env.now}] Migrated #{data_id} {evicted_size}MB from {self.name} to {self.lower_tier.name}")

                # Remove migrated data blocks from the current tier
                data_blocks_to_evict = []
                evicted_size_total = 0
                for block_id, (size, _) in list(self.data_blocks.items()):
                    if evicted_size_total + size <= evicted_size:
                        data_blocks_to_evict.append(block_id)
                        evicted_size_total += size
                for block_id in data_blocks_to_evict:
                    del self.data_blocks[block_id]
                    self.utilization -= size
                # --- End of existing logic ---

            else:
                print(f"[{self.env.now}] Lower tier ({self.lower_tier.name}) full, cascading eviction...")
                # Trigger eviction on the lower tier to make space
                yield self.env.process(self.lower_tier.migrate_data(data_size, data_id))
                # Now that lower tier has space, retry migration
                yield self.env.process(self.migrate_data(data_size, data_id))

        else:
            print(f"[{self.env.now}] No lower tier available for migration")
            yield self.env.timeout(0)  # Act as a generator

# %%
class TieredFileSystem:
    def __init__(self, env):
        # Create storage tiers and link them in order
        self.env = env  # Store the env object as an attribute
        self.tier3 = StorageTier(env, "Tier 3", 5000000, 100, 50)
        self.tier2 = StorageTier(env, "Tier 2", 10000, 500, 20, self.tier3)
        self.tier1 = StorageTier(env, "Tier 1", 1000, 1000, 10, self.tier2)
        self.tier0 = StorageTier(env, "Tier 0", 300, 5000, 5, self.tier1)
        self.dram = StorageTier(env, "DRAM", 100, 10000, 1, self.tier0)

        self.tiers = {
            "DRAM": self.dram,
            "Tier 0": self.tier0,
            "Tier 1": self.tier1,
            "Tier 2": self.tier2,
            "Tier 3": self.tier3
        }

        self.access_history = collections.deque(maxlen=100)  # Store the last 100 accesses


        # Fix: Ensure lower_tier is correctly set for Tier 1
        # self.tier3.lower_tier = self.tier2

    def access_data(self, tier_name, data_size, is_write=True, data_id=None):
        """Send an I/O request, considering data temperature for writes."""
        tier = self.tiers[tier_name]

        if is_write:
            # Check DRAM and Tier 0 utilization
            dram_utilization = self.dram.utilization / self.dram.capacity
            tier0_utilization = self.tier0.utilization / self.tier0.capacity

            # Prioritize DRAM if utilization is below 80%
            if dram_utilization < 0.8:
                target_tier = self.dram
            else:
                # If DRAM is full, check Tier 0 utilization
                tier0_utilization = self.tier0.utilization / self.tier0.capacity
                if tier0_utilization < 0.8:
                    target_tier = self.tier0
                else:
                    # Otherwise, use data temperature for tier selection
                    data_temperature = self.get_data_temperature(data_id)
                    if data_temperature == "hot":
                        target_tier = self.dram
                    elif data_temperature == "warm":
                        target_tier = self.tier0
                    else:  # cold
                        target_tier = self.tier1

            target_tier.request_io("write", data_size, data_id)

        else:  # Read operations
            # Find the tier where data_id is stored
            data_tier = self.find_data_tier(data_id)

            if data_tier is None:
                print(f"[{self.env.now}] Data #{data_id} not found in any tier.")
                return  # Exit if data not found

            # Enforce read operation on the correct tier
            if data_tier.name != tier_name:
                print(f"[{self.env.now}] Read request for #{data_id} on {tier_name}, but data is in {data_tier.name}. Redirecting...")

            data_tier.request_io("read", data_size, data_id)  # Read from the correct tier
            self.access_history.append(data_id)  # Update access history on read

    def find_data_tier(self, data_id):
        """Find the tier where the data_id is stored."""
        for tier_name, tier in self.tiers.items():
            if data_id in tier.data_blocks:
                return tier
        return None  # Return None if data_id not found in any tier


    def get_data_temperature(self, data_id):
        """Categorize data temperature based on access frequency."""
        if data_id is None:
            return "cold"  # Default to cold for new data

        access_count = self.access_history.count(data_id)
        if access_count >= 10:  # Adjust threshold as needed
            return "hot"
        elif access_count >= 5:  # Adjust threshold as needed
            return "warm"
        else:
            return "cold"



    def migrate_to_tier_1(self, target_tier, data_size):
        """Migrate data from a lower tier (Tier 2 or 3) to Tier 1."""
        current_tier = target_tier
        while current_tier.name != "Tier 1" and current_tier.lower_tier is not None:
            upper_tier = current_tier.lower_tier  # Get the next higher tier

            # Check if upper tier has enough space, otherwise trigger eviction
            if not upper_tier.can_store(data_size):
                print(f"[{self.env.now}] {upper_tier.name} is full, triggering eviction to make space...")
                yield self.env.process(upper_tier.migrate_data(data_size)) # Evict from upper tier

            # Migrate data to the upper tier
            yield self.env.process(current_tier.migrate_data(data_size))

            current_tier = upper_tier

        print(f"[{self.env.now}] Data migrated to Tier 1 for reading.")
        self.tier1.request_io("read", data_size) #Initiate read on tier 1

def workload(env, fs):
    """Simulated workload: random reads/writes with increased activity."""
    written_data_sizes = {}  # Dictionary to store written data sizes
    operation_count = 0  # Counter for operations

    # Guarantee at least one initial write
    tier = "DRAM"
    data_id = random.randint(1, 1000)  # Random data ID
    size = random.randint(1, 50)  # Wider range of data sizes
    fs.access_data(tier, size, True, data_id) # Perform an initial write
    written_data_sizes[data_id] = size  # Store written data size


    for _ in range(500):  # Increased number of requests
        is_write = random.choice([True, False])
        data_id = None # Initialize data_id to None for each iteration
        operation_count += 1
        print(f"operation id: {operation_count}")

        if is_write:
            tier = "DRAM"
            data_id = random.randint(1, 1000)  # Random data ID
            size = random.randint(1, 20)  # Wider range of data sizes
            fs.access_data(tier, size, is_write, data_id)
            written_data_sizes[data_id] = size  # Store written data size

        else:
            if written_data_sizes:  # Check if there are written data IDs
                data_id = random.choice(list(written_data_sizes.keys()))
                # Find the tier where data_id is stored
                data_tier = fs.find_data_tier(data_id)

                if data_tier is not None:
                    tier = data_tier.name  # Get the tier name
                    size = random.randint(1, max(1, written_data_sizes[data_id] - 1))
                    fs.access_data(tier, size, is_write, data_id)  # Pass data_id for reads
                else:
                    print(f"[{env.now}] Data #{data_id} not found for read operation.")

        if data_id is not None:
            print(f"operation id: {operation_count} WriteRead#: {is_write} data_id: {data_id} tier: {tier}")

        if operation_count % 10 == 0:
            print("\n--- Tier Utilization ---")
            for tier_name, tier in fs.tiers.items():
                print(f"{tier_name}: {tier.utilization}/{tier.capacity} ({tier.utilization / tier.capacity * 100:.2f}%)")
            print("------------------------\n")

        yield env.timeout(random.uniform(0.1, 2))  # Shorter, more frequent timeouts


env = simpy.Environment()
fs = TieredFileSystem(env)

# Run the simulation
env.process(workload(env, fs))
env.run(until=10000)  # Run simulation for 50 time units
# Out:
# operation id: 1
# operation id: 1 WriteRead#: True data_id: 64 tier: DRAM
# [0.0052] Wrote #832 42MB to DRAM
# [0.006999999999999999] Wrote #64 8MB to DRAM
# operation id: 2
# operation id: 2 WriteRead#: False data_id: 64 tier: DRAM
# [0.34912823011557664] Read #64 6MB from DRAM
# operation id: 3
# operation id: 3 WriteRead#: True data_id: 672 tier: DRAM
# [0.68379376699151] Wrote #672 3MB to DRAM
# operation id: 4
# operation id: 4 WriteRead#: False data_id: 832 tier: DRAM
# [2.304940491669866] Read #832 31MB from DRAM
# operation id: 5
# operation id: 5 WriteRead#: False data_id: 64 tier: DRAM
# [4.168993257656295] Read #64 5MB from DRAM
# operation id: 6
# operation id: 6 WriteRead#: False data_id: 672 tier: DRAM
# [5.549350389716414] Read #672 2MB from DRAM
# operation id: 7
# operation id: 7 WriteRead#: False data_id: 832 tier: DRAM
# [6.71165658699686] Read #832 14MB from DRAM
# operation id: 8
# operation id: 8 WriteRead#: True data_id: 740 tier: DRAM
# [7.913700426003086] Wrote #740 8MB to DRAM
# operation id: 9
# operation id: 9 WriteRead#: False data_id: 64 tier: DRAM
# [9.323788291580819] Read #64 2MB from DRAM
# operation id: 10
# operation id: 10 WriteRead#: True data_id: 153 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 61/100 (61.00%)
# Tier 0: 0/300 (0.00%)
# Tier 1: 0/1000 (0.00%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [10.387266145770388] Wrote #153 10MB to DRAM
# operation id: 11
# operation id: 11 WriteRead#: False data_id: 153 tier: DRAM
# [10.894820530112554] Read #153 3MB from DRAM
# operation id: 12
# operation id: 12 WriteRead#: False data_id: 740 tier: DRAM
# [11.671045253212048] Read #740 6MB from DRAM
# operation id: 13
# operation id: 13 WriteRead#: True data_id: 99 tier: DRAM
# [13.086015396725706] Wrote #99 3MB to DRAM
# operation id: 14
# operation id: 14 WriteRead#: True data_id: 961 tier: DRAM
# [13.440374798149865] Wrote #961 20MB to DRAM
# operation id: 15
# operation id: 15 WriteRead#: True data_id: 792 tier: DRAM
# [14.536414303281859] Wrote #792 6MB to Tier 0
# operation id: 16
# operation id: 16 WriteRead#: True data_id: 128 tier: DRAM
# [14.796947559151771] Wrote #128 16MB to Tier 0
# operation id: 17
# operation id: 17 WriteRead#: False data_id: 832 tier: DRAM
# [16.663978769854936] Read #832 39MB from DRAM
# operation id: 18
# operation id: 18 WriteRead#: False data_id: 128 tier: Tier 0
# [17.34780962060943] Read #128 7MB from Tier 0
# operation id: 19
# operation id: 19 WriteRead#: True data_id: 396 tier: DRAM
# [17.815514197908204] Wrote #396 9MB to Tier 0
# operation id: 20
# operation id: 20 WriteRead#: False data_id: 961 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 31/300 (10.33%)
# Tier 1: 0/1000 (0.00%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [18.2632225944947] Read #961 6MB from DRAM
# operation id: 21
# operation id: 21 WriteRead#: False data_id: 396 tier: Tier 0
# [18.93763821099234] Read #396 1MB from Tier 0
# operation id: 22
# operation id: 22 WriteRead#: True data_id: 851 tier: DRAM
# [20.86467526585759] Wrote #851 8MB to Tier 0
# operation id: 23
# operation id: 23 WriteRead#: True data_id: 681 tier: DRAM
# [22.182165472121078] Wrote #681 19MB to Tier 0
# operation id: 24
# operation id: 24 WriteRead#: True data_id: 807 tier: DRAM
# [22.762921105151854] Wrote #807 11MB to Tier 0
# operation id: 25
# operation id: 25 WriteRead#: False data_id: 396 tier: Tier 0
# [24.327932985289983] Read #396 2MB from Tier 0
# operation id: 26
# operation id: 26 WriteRead#: True data_id: 267 tier: DRAM
# [24.541266381096204] Wrote #267 12MB to Tier 0
# operation id: 27
# operation id: 27 WriteRead#: True data_id: 794 tier: DRAM
# [25.300888320947433] Wrote #794 4MB to Tier 0
# operation id: 28
# operation id: 28 WriteRead#: True data_id: 62 tier: DRAM
# [26.96739636584799] Wrote #62 3MB to Tier 0
# operation id: 29
# operation id: 29 WriteRead#: True data_id: 553 tier: DRAM
# [27.082381408210757] Wrote #553 3MB to Tier 0
# operation id: 30
# operation id: 30 WriteRead#: True data_id: 742 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 91/300 (30.33%)
# Tier 1: 0/1000 (0.00%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [28.513149511386455] Wrote #742 20MB to Tier 0
# operation id: 31
# operation id: 31 WriteRead#: True data_id: 708 tier: DRAM
# [30.3780578711086] Wrote #708 5MB to Tier 0
# operation id: 32
# operation id: 32 WriteRead#: False data_id: 396 tier: Tier 0
# [31.05065238422082] Read #396 1MB from Tier 0
# operation id: 33
# operation id: 33 WriteRead#: True data_id: 842 tier: DRAM
# [31.269037712600863] Wrote #842 17MB to Tier 0
# operation id: 34
# operation id: 34 WriteRead#: True data_id: 20 tier: DRAM
# [32.78859719772207] Wrote #20 19MB to Tier 0
# operation id: 35
# operation id: 35 WriteRead#: True data_id: 550 tier: DRAM
# [33.68526397512908] Wrote #550 2MB to Tier 0
# operation id: 36
# operation id: 36 WriteRead#: False data_id: 708 tier: Tier 0
# [35.64827775613147] Read #708 1MB from Tier 0
# operation id: 37
# operation id: 37 WriteRead#: True data_id: 251 tier: DRAM
# [36.81789536636281] Wrote #251 19MB to Tier 0
# operation id: 38
# operation id: 38 WriteRead#: False data_id: 794 tier: Tier 0
# [37.511631777437955] Read #794 3MB from Tier 0
# operation id: 39
# operation id: 39 WriteRead#: True data_id: 103 tier: DRAM
# [38.125326696017694] Wrote #103 7MB to Tier 0
# operation id: 40
# operation id: 40 WriteRead#: False data_id: 832 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 180/300 (60.00%)
# Tier 1: 0/1000 (0.00%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [39.9061551675096] Read #832 38MB from DRAM
# operation id: 41
# operation id: 41 WriteRead#: False data_id: 20 tier: Tier 0
# [40.97967903339414] Read #20 17MB from Tier 0
# operation id: 42
# operation id: 42 WriteRead#: False data_id: 792 tier: Tier 0
# [42.582678754993466] Read #792 1MB from Tier 0
# operation id: 43
# operation id: 43 WriteRead#: False data_id: 99 tier: DRAM
# [43.80554910372539] Read #99 2MB from DRAM
# operation id: 44
# operation id: 44 WriteRead#: False data_id: 740 tier: DRAM
# [45.67902193599489] Read #740 2MB from DRAM
# operation id: 45
# operation id: 45 WriteRead#: False data_id: 128 tier: Tier 0
# [46.89684144146401] Read #128 1MB from Tier 0
# operation id: 46
# operation id: 46 WriteRead#: True data_id: 897 tier: DRAM
# [47.480739033001676] Wrote #897 3MB to Tier 0
# operation id: 47
# operation id: 47 WriteRead#: False data_id: 99 tier: DRAM
# [47.705425375207994] Read #99 2MB from DRAM
# operation id: 48
# operation id: 48 WriteRead#: True data_id: 590 tier: DRAM
# [49.16303614009332] Wrote #590 15MB to Tier 0
# operation id: 49
# operation id: 49 WriteRead#: False data_id: 681 tier: Tier 0
# [50.151829742720864] Read #681 17MB from Tier 0
# operation id: 50
# operation id: 50 WriteRead#: False data_id: 897 tier: Tier 0
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 198/300 (66.00%)
# Tier 1: 0/1000 (0.00%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [52.05958058194063] Read #897 1MB from Tier 0
# operation id: 51
# operation id: 51 WriteRead#: True data_id: 626 tier: DRAM
# [53.28623668053432] Wrote #626 14MB to Tier 0
# operation id: 52
# operation id: 52 WriteRead#: False data_id: 792 tier: Tier 0
# [53.99844363545222] Read #792 3MB from Tier 0
# operation id: 53
# operation id: 53 WriteRead#: True data_id: 528 tier: DRAM
# [54.658184598204265] Wrote #528 5MB to Tier 0
# operation id: 54
# operation id: 54 WriteRead#: False data_id: 251 tier: Tier 0
# [55.35316057459812] Read #251 15MB from Tier 0
# operation id: 55
# operation id: 55 WriteRead#: False data_id: 267 tier: Tier 0
# [55.7528186850767] Read #267 9MB from Tier 0
# operation id: 56
# operation id: 56 WriteRead#: False data_id: 672 tier: DRAM
# [56.08174454277367] Read #672 1MB from DRAM
# operation id: 57
# operation id: 57 WriteRead#: False data_id: 708 tier: Tier 0
# [56.209107181114156] Read #708 3MB from Tier 0
# operation id: 58
# operation id: 58 WriteRead#: False data_id: 99 tier: DRAM
# [57.22283866215481] Read #99 2MB from DRAM
# operation id: 59
# operation id: 59 WriteRead#: True data_id: 531 tier: DRAM
# [58.73342524059012] Wrote #531 20MB to Tier 0
# operation id: 60
# operation id: 60 WriteRead#: False data_id: 251 tier: Tier 0
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 237/300 (79.00%)
# Tier 1: 0/1000 (0.00%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [59.75558421476587] Read #251 6MB from Tier 0
# operation id: 61
# operation id: 61 WriteRead#: True data_id: 259 tier: DRAM
# [61.357812280661676] Wrote #259 14MB to Tier 0
# operation id: 62
# operation id: 62 WriteRead#: True data_id: 705 tier: DRAM
# [62.96838729786642] Wrote #705 9MB to Tier 1
# operation id: 63
# operation id: 63 WriteRead#: True data_id: 375 tier: DRAM
# [64.75175795702367] Wrote #375 6MB to Tier 1
# operation id: 64
# operation id: 64 WriteRead#: False data_id: 62 tier: Tier 0
# [65.17289614717481] Read #62 1MB from Tier 0
# operation id: 65
# operation id: 65 WriteRead#: False data_id: 794 tier: Tier 0
# [65.76008654518782] Read #794 3MB from Tier 0
# operation id: 66
# operation id: 66 WriteRead#: False data_id: 851 tier: Tier 0
# [67.48080690456403] Read #851 3MB from Tier 0
# operation id: 67
# operation id: 67 WriteRead#: False data_id: 897 tier: Tier 0
# [69.38098845274936] Read #897 1MB from Tier 0
# operation id: 68
# operation id: 68 WriteRead#: True data_id: 899 tier: DRAM
# [70.01610253902753] Wrote #899 19MB to Tier 1
# operation id: 69
# operation id: 69 WriteRead#: True data_id: 810 tier: DRAM
# [71.90557353105913] Wrote #810 1MB to Tier 1
# operation id: 70
# operation id: 70 WriteRead#: True data_id: 848 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 35/1000 (3.50%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [72.91118585421714] Wrote #848 19MB to Tier 1
# operation id: 71
# operation id: 71 WriteRead#: False data_id: 848 tier: Tier 1
# [74.31364848838274] Read #848 2MB from Tier 1
# operation id: 72
# operation id: 72 WriteRead#: False data_id: 128 tier: Tier 0
# [74.47904136213332] Read #128 9MB from Tier 0
# operation id: 73
# operation id: 73 WriteRead#: True data_id: 632 tier: DRAM
# [75.43371505350328] Wrote #632 8MB to Tier 1
# operation id: 74
# operation id: 74 WriteRead#: True data_id: 231 tier: DRAM
# [75.82238434279743] Wrote #231 1MB to Tier 1
# operation id: 75
# operation id: 75 WriteRead#: False data_id: 62 tier: Tier 0
# [77.63849414775348] Read #62 2MB from Tier 0
# operation id: 76
# operation id: 76 WriteRead#: True data_id: 324 tier: DRAM
# [77.8664325819197] Wrote #324 12MB to Tier 1
# operation id: 77
# operation id: 77 WriteRead#: False data_id: 251 tier: Tier 0
# [78.99827646785434] Read #251 14MB from Tier 0
# operation id: 78
# operation id: 78 WriteRead#: True data_id: 204 tier: DRAM
# [80.53807342237529] Wrote #204 17MB to Tier 1
# operation id: 79
# operation id: 79 WriteRead#: True data_id: 881 tier: DRAM
# [81.78661826308087] Wrote #881 6MB to Tier 1
# operation id: 80
# operation id: 80 WriteRead#: False data_id: 231 tier: Tier 1
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 98/1000 (9.80%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [82.65205756266334] Read #231 1MB from Tier 1
# operation id: 81
# operation id: 81 WriteRead#: True data_id: 274 tier: DRAM
# [83.450790485449] Wrote #274 6MB to Tier 1
# operation id: 82
# operation id: 82 WriteRead#: True data_id: 333 tier: DRAM
# [84.24907312867329] Wrote #333 3MB to Tier 1
# operation id: 83
# operation id: 83 WriteRead#: True data_id: 606 tier: DRAM
# [84.94665764010803] Wrote #606 2MB to Tier 1
# operation id: 84
# operation id: 84 WriteRead#: True data_id: 86 tier: DRAM
# [86.10916971557357] Wrote #86 19MB to Tier 1
# operation id: 85
# operation id: 85 WriteRead#: True data_id: 453 tier: DRAM
# [88.05063012417858] Wrote #453 9MB to Tier 1
# operation id: 86
# operation id: 86 WriteRead#: False data_id: 128 tier: Tier 0
# [88.23817849291241] Read #128 1MB from Tier 0
# operation id: 87
# operation id: 87 WriteRead#: False data_id: 848 tier: Tier 1
# [89.864072904342] Read #848 18MB from Tier 1
# operation id: 88
# operation id: 88 WriteRead#: False data_id: 810 tier: Tier 1
# [91.83965354023778] Read #810 1MB from Tier 1
# operation id: 89
# operation id: 89 WriteRead#: True data_id: 439 tier: DRAM
# [92.50608768229894] Wrote #439 19MB to Tier 1
# operation id: 90
# operation id: 90 WriteRead#: True data_id: 110 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 156/1000 (15.60%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [93.66239823446902] Wrote #110 11MB to Tier 1
# operation id: 91
# operation id: 91 WriteRead#: True data_id: 633 tier: DRAM
# [93.86260332544256] Wrote #633 16MB to Tier 1
# operation id: 92
# operation id: 92 WriteRead#: True data_id: 497 tier: DRAM
# [95.03352673114644] Wrote #497 2MB to Tier 1
# operation id: 93
# operation id: 93 WriteRead#: False data_id: 231 tier: Tier 1
# [96.00373738095965] Read #231 1MB from Tier 1
# operation id: 94
# operation id: 94 WriteRead#: False data_id: 439 tier: Tier 1
# [97.15987948192522] Read #439 11MB from Tier 1
# operation id: 95
# operation id: 95 WriteRead#: True data_id: 991 tier: DRAM
# [98.4391483324033] Wrote #991 2MB to Tier 1
# operation id: 96
# operation id: 96 WriteRead#: True data_id: 715 tier: DRAM
# [98.74736443370476] Wrote #715 2MB to Tier 1
# operation id: 97
# operation id: 97 WriteRead#: False data_id: 274 tier: Tier 1
# [99.0510501084929] Read #274 2MB from Tier 1
# operation id: 98
# operation id: 98 WriteRead#: False data_id: 231 tier: Tier 1
# [99.84928849137019] Read #231 1MB from Tier 1
# operation id: 99
# operation id: 99 WriteRead#: False data_id: 20 tier: Tier 0
# [100.83787046056564] Read #20 9MB from Tier 0
# operation id: 100
# operation id: 100 WriteRead#: False data_id: 590 tier: Tier 0
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 189/1000 (18.90%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [101.71382051861819] Read #590 4MB from Tier 0
# operation id: 101
# operation id: 101 WriteRead#: False data_id: 899 tier: Tier 1
# [103.62912372474649] Read #899 6MB from Tier 1
# operation id: 102
# operation id: 102 WriteRead#: True data_id: 280 tier: DRAM
# [105.14311153807515] Wrote #280 20MB to Tier 1
# operation id: 103
# operation id: 103 WriteRead#: True data_id: 364 tier: DRAM
# [105.61288324760682] Wrote #364 15MB to Tier 1
# operation id: 104
# operation id: 104 WriteRead#: False data_id: 497 tier: Tier 1
# [106.38572373418423] Read #497 1MB from Tier 1
# operation id: 105
# operation id: 105 WriteRead#: True data_id: 94 tier: DRAM
# [106.86068610100862] Wrote #94 9MB to Tier 1
# operation id: 106
# operation id: 106 WriteRead#: True data_id: 239 tier: DRAM
# [107.00492203165962] Wrote #239 9MB to Tier 1
# operation id: 107
# operation id: 107 WriteRead#: False data_id: 881 tier: Tier 1
# [108.99028542711379] Read #881 1MB from Tier 1
# operation id: 108
# operation id: 108 WriteRead#: False data_id: 961 tier: DRAM
# [110.40117615944442] Read #961 8MB from DRAM
# operation id: 109
# operation id: 109 WriteRead#: True data_id: 284 tier: DRAM
# [111.3839590758696] Wrote #284 13MB to Tier 1
# operation id: 110
# operation id: 110 WriteRead#: True data_id: 573 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 255/1000 (25.50%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [113.27340590825972] Wrote #573 14MB to Tier 1
# operation id: 111
# operation id: 111 WriteRead#: True data_id: 360 tier: DRAM
# [114.60393690948014] Wrote #360 3MB to Tier 1
# operation id: 112
# operation id: 112 WriteRead#: False data_id: 842 tier: Tier 0
# [116.09558012584398] Read #842 9MB from Tier 0
# operation id: 113
# operation id: 113 WriteRead#: False data_id: 333 tier: Tier 1
# [116.59198979804903] Read #333 1MB from Tier 1
# operation id: 114
# operation id: 114 WriteRead#: False data_id: 794 tier: Tier 0
# [117.72585111757314] Read #794 1MB from Tier 0
# operation id: 115
# operation id: 115 WriteRead#: True data_id: 314 tier: DRAM
# [118.82370899271146] Wrote #314 8MB to Tier 1
# operation id: 116
# operation id: 116 WriteRead#: False data_id: 553 tier: Tier 0
# [119.76950286366133] Read #553 1MB from Tier 0
# operation id: 117
# operation id: 117 WriteRead#: True data_id: 592 tier: DRAM
# [120.42826165501884] Wrote #592 3MB to Tier 1
# operation id: 118
# operation id: 118 WriteRead#: True data_id: 193 tier: DRAM
# [122.28145773231273] Wrote #193 7MB to Tier 1
# operation id: 119
# operation id: 119 WriteRead#: True data_id: 308 tier: DRAM
# [123.2529861117115] Wrote #308 18MB to Tier 1
# operation id: 120
# operation id: 120 WriteRead#: False data_id: 62 tier: Tier 0
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 308/1000 (30.80%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [124.7556891123871] Read #62 2MB from Tier 0
# operation id: 121
# operation id: 121 WriteRead#: False data_id: 897 tier: Tier 0
# [125.33171772217497] Read #897 2MB from Tier 0
# operation id: 122
# operation id: 122 WriteRead#: True data_id: 513 tier: DRAM
# [126.35544206529299] Wrote #513 1MB to Tier 1
# operation id: 123
# operation id: 123 WriteRead#: True data_id: 554 tier: DRAM
# [128.04858349779033] Wrote #554 12MB to Tier 1
# operation id: 124
# operation id: 124 WriteRead#: True data_id: 9 tier: DRAM
# [128.90469812158278] Wrote #9 6MB to Tier 1
# operation id: 125
# operation id: 125 WriteRead#: True data_id: 59 tier: DRAM
# [130.0972007123428] Wrote #59 10MB to Tier 1
# operation id: 126
# operation id: 126 WriteRead#: True data_id: 510 tier: DRAM
# [131.57977389552192] Wrote #510 7MB to Tier 1
# operation id: 127
# operation id: 127 WriteRead#: True data_id: 937 tier: DRAM
# [132.18274712062606] Wrote #937 14MB to Tier 1
# operation id: 128
# operation id: 128 WriteRead#: False data_id: 280 tier: Tier 1
# [133.1006307424425] Read #280 5MB from Tier 1
# operation id: 129
# operation id: 129 WriteRead#: True data_id: 181 tier: DRAM
# [133.90775672642124] Wrote #181 17MB to Tier 1
# operation id: 130
# operation id: 130 WriteRead#: True data_id: 748 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 375/1000 (37.50%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [134.5436078111347] Wrote #748 8MB to Tier 1
# operation id: 131
# operation id: 131 WriteRead#: False data_id: 86 tier: Tier 1
# [136.414874683379] Read #86 9MB from Tier 1
# operation id: 132
# operation id: 132 WriteRead#: False data_id: 592 tier: Tier 1
# [137.85236041606683] Read #592 1MB from Tier 1
# operation id: 133
# operation id: 133 WriteRead#: False data_id: 94 tier: Tier 1
# [139.31548191957546] Read #94 3MB from Tier 1
# operation id: 134
# operation id: 134 WriteRead#: True data_id: 944 tier: DRAM
# [140.01905988975327] Wrote #944 14MB to Tier 1
# operation id: 135
# operation id: 135 WriteRead#: True data_id: 721 tier: DRAM
# [140.3322510187251] Wrote #721 7MB to Tier 1
# operation id: 136
# operation id: 136 WriteRead#: True data_id: 68 tier: DRAM
# [141.98338278676195] Wrote #68 9MB to Tier 1
# operation id: 137
# operation id: 137 WriteRead#: True data_id: 903 tier: DRAM
# [143.70138135881487] Wrote #903 13MB to Tier 1
# operation id: 138
# operation id: 138 WriteRead#: True data_id: 242 tier: DRAM
# [145.2478421755096] Wrote #242 16MB to Tier 1
# operation id: 139
# operation id: 139 WriteRead#: False data_id: 513 tier: Tier 1
# [146.66592296376874] Read #513 1MB from Tier 1
# operation id: 140
# operation id: 140 WriteRead#: True data_id: 729 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 442/1000 (44.20%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [147.87113413654268] Wrote #729 5MB to Tier 1
# operation id: 141
# operation id: 141 WriteRead#: False data_id: 681 tier: Tier 0
# [148.07125466142568] Read #681 7MB from Tier 0
# operation id: 142
# operation id: 142 WriteRead#: True data_id: 548 tier: DRAM
# [148.9835377960317] Wrote #548 6MB to Tier 1
# operation id: 143
# operation id: 143 WriteRead#: True data_id: 751 tier: DRAM
# [150.32413582130567] Wrote #751 11MB to Tier 1
# operation id: 144
# operation id: 144 WriteRead#: True data_id: 351 tier: DRAM
# [151.09271769642493] Wrote #351 14MB to Tier 1
# operation id: 145
# operation id: 145 WriteRead#: True data_id: 194 tier: DRAM
# [152.98233750506043] Wrote #194 2MB to Tier 1
# operation id: 146
# operation id: 146 WriteRead#: True data_id: 279 tier: DRAM
# [154.80209864566405] Wrote #279 15MB to Tier 1
# operation id: 147
# operation id: 147 WriteRead#: False data_id: 9 tier: Tier 1
# [155.5551530611424] Read #9 2MB from Tier 1
# operation id: 148
# operation id: 148 WriteRead#: False data_id: 86 tier: Tier 1
# [156.5096028015887] Read #86 9MB from Tier 1
# operation id: 149
# operation id: 149 WriteRead#: False data_id: 554 tier: Tier 1
# [157.49061470503904] Read #554 11MB from Tier 1
# operation id: 150
# operation id: 150 WriteRead#: True data_id: 194 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 495/1000 (49.50%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [158.16455049588473] Wrote #194 9MB to Tier 1
# operation id: 151
# operation id: 151 WriteRead#: True data_id: 588 tier: DRAM
# [158.72558975293097] Wrote #588 10MB to Tier 1
# operation id: 152
# operation id: 152 WriteRead#: False data_id: 360 tier: Tier 1
# [160.03258689042357] Read #360 1MB from Tier 1
# operation id: 153
# operation id: 153 WriteRead#: False data_id: 633 tier: Tier 1
# [161.9256892470176] Read #633 4MB from Tier 1
# operation id: 154
# operation id: 154 WriteRead#: True data_id: 105 tier: DRAM
# [162.1517234443819] Wrote #105 10MB to Tier 1
# operation id: 155
# operation id: 155 WriteRead#: True data_id: 283 tier: DRAM
# [163.9045118294639] Wrote #283 1MB to Tier 1
# operation id: 156
# operation id: 156 WriteRead#: False data_id: 497 tier: Tier 1
# [164.19779741067921] Read #497 1MB from Tier 1
# operation id: 157
# operation id: 157 WriteRead#: False data_id: 333 tier: Tier 1
# [165.12482864011443] Read #333 1MB from Tier 1
# operation id: 158
# operation id: 158 WriteRead#: True data_id: 328 tier: DRAM
# [166.09665283557956] Wrote #328 7MB to Tier 1
# operation id: 159
# operation id: 159 WriteRead#: True data_id: 55 tier: DRAM
# [166.72557213581956] Wrote #55 3MB to Tier 1
# operation id: 160
# operation id: 160 WriteRead#: False data_id: 810 tier: Tier 1
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 535/1000 (53.50%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [167.6923444032522] Read #810 1MB from Tier 1
# operation id: 161
# operation id: 161 WriteRead#: False data_id: 128 tier: Tier 0
# [168.6866800782151] Read #128 3MB from Tier 0
# operation id: 162
# operation id: 162 WriteRead#: False data_id: 881 tier: Tier 1
# [168.86294511078685] Read #881 5MB from Tier 1
# operation id: 163
# operation id: 163 WriteRead#: False data_id: 550 tier: Tier 0
# [169.03339955914512] Read #550 1MB from Tier 0
# operation id: 164
# operation id: 164 WriteRead#: False data_id: 351 tier: Tier 1
# [170.17600307424968] Read #351 12MB from Tier 1
# operation id: 165
# operation id: 165 WriteRead#: True data_id: 833 tier: DRAM
# [170.34857214523794] Wrote #833 14MB to Tier 1
# operation id: 166
# operation id: 166 WriteRead#: True data_id: 8 tier: DRAM
# [171.86419597129162] Wrote #8 5MB to Tier 1
# operation id: 167
# operation id: 167 WriteRead#: True data_id: 55 tier: DRAM
# [172.69281021960188] Wrote #55 10MB to Tier 1
# operation id: 168
# operation id: 168 WriteRead#: True data_id: 976 tier: DRAM
# [172.8207413843417] Wrote #976 14MB to Tier 1
# operation id: 169
# operation id: 169 WriteRead#: True data_id: 626 tier: DRAM
# [172.9629676674039] Wrote #626 15MB to Tier 1
# operation id: 170
# operation id: 170 WriteRead#: False data_id: 64 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 593/1000 (59.30%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [173.14033527235998] Read #64 4MB from DRAM
# operation id: 171
# operation id: 171 WriteRead#: True data_id: 575 tier: DRAM
# [174.9643342965942] Wrote #575 13MB to Tier 1
# operation id: 172
# operation id: 172 WriteRead#: False data_id: 99 tier: DRAM
# [175.72939977634954] Read #99 1MB from DRAM
# operation id: 173
# operation id: 173 WriteRead#: False data_id: 944 tier: Tier 1
# [177.7190306176249] Read #944 2MB from Tier 1
# operation id: 174
# operation id: 174 WriteRead#: True data_id: 463 tier: DRAM
# [178.5194192858307] Wrote #463 10MB to Tier 1
# operation id: 175
# operation id: 175 WriteRead#: False data_id: 606 tier: Tier 1
# [178.73841775643342] Read #606 1MB from Tier 1
# operation id: 176
# operation id: 176 WriteRead#: False data_id: 251 tier: Tier 0
# [179.61329566172077] Read #251 3MB from Tier 0
# operation id: 177
# operation id: 177 WriteRead#: False data_id: 351 tier: Tier 1
# [179.83030339528491] Read #351 13MB from Tier 1
# operation id: 178
# operation id: 178 WriteRead#: True data_id: 513 tier: DRAM
# [181.02813297469802] Wrote #513 6MB to Tier 1
# operation id: 179
# operation id: 179 WriteRead#: False data_id: 110 tier: Tier 1
# [182.72719306470935] Read #110 6MB from Tier 1
# operation id: 180
# operation id: 180 WriteRead#: True data_id: 720 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 622/1000 (62.20%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [183.50610523818722] Wrote #720 14MB to Tier 1
# operation id: 181
# operation id: 181 WriteRead#: False data_id: 105 tier: Tier 1
# [184.35886560795453] Read #105 1MB from Tier 1
# operation id: 182
# operation id: 182 WriteRead#: False data_id: 899 tier: Tier 1
# [185.03316173378934] Read #899 9MB from Tier 1
# operation id: 183
# operation id: 183 WriteRead#: False data_id: 231 tier: Tier 1
# [185.29936360540736] Read #231 1MB from Tier 1
# operation id: 184
# operation id: 184 WriteRead#: False data_id: 324 tier: Tier 1
# [185.6994846789758] Read #324 10MB from Tier 1
# operation id: 185
# operation id: 185 WriteRead#: False data_id: 284 tier: Tier 1
# [186.83062035297925] Read #284 9MB from Tier 1
# operation id: 186
# operation id: 186 WriteRead#: False data_id: 259 tier: Tier 0
# [187.14093176553155] Read #259 13MB from Tier 0
# operation id: 187
# operation id: 187 WriteRead#: True data_id: 448 tier: DRAM
# [188.60026885755917] Wrote #448 11MB to Tier 1
# operation id: 188
# operation id: 188 WriteRead#: False data_id: 606 tier: Tier 1
# [189.0944434991886] Read #606 1MB from Tier 1
# operation id: 189
# operation id: 189 WriteRead#: True data_id: 560 tier: DRAM
# [189.86554314376517] Wrote #560 9MB to Tier 1
# operation id: 190
# operation id: 190 WriteRead#: False data_id: 833 tier: Tier 1
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 656/1000 (65.60%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [189.98853623733473] Read #833 8MB from Tier 1
# operation id: 191
# operation id: 191 WriteRead#: True data_id: 388 tier: DRAM
# [191.23656415864966] Wrote #388 15MB to Tier 1
# operation id: 192
# operation id: 192 WriteRead#: True data_id: 789 tier: DRAM
# [191.448125392591] Wrote #789 2MB to Tier 1
# operation id: 193
# operation id: 193 WriteRead#: False data_id: 961 tier: DRAM
# [192.28790294748333] Read #961 12MB from DRAM
# operation id: 194
# operation id: 194 WriteRead#: False data_id: 110 tier: Tier 1
# [194.1412909757033] Read #110 6MB from Tier 1
# operation id: 195
# operation id: 195 WriteRead#: False data_id: 833 tier: Tier 1
# [195.470126892086] Read #833 6MB from Tier 1
# operation id: 196
# operation id: 196 WriteRead#: False data_id: 497 tier: Tier 1
# [196.53368454811246] Read #497 1MB from Tier 1
# operation id: 197
# operation id: 197 WriteRead#: False data_id: 742 tier: Tier 0
# [197.40764600687962] Read #742 14MB from Tier 0
# operation id: 198
# operation id: 198 WriteRead#: True data_id: 856 tier: DRAM
# [199.1202955014678] Wrote #856 2MB to Tier 1
# operation id: 199
# operation id: 199 WriteRead#: True data_id: 214 tier: DRAM
# [200.32764781585647] Wrote #214 14MB to Tier 1
# operation id: 200
# operation id: 200 WriteRead#: True data_id: 553 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 689/1000 (68.90%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [201.571584298404] Wrote #553 17MB to Tier 1
# operation id: 201
# operation id: 201 WriteRead#: False data_id: 575 tier: Tier 1
# [203.43125803728108] Read #575 8MB from Tier 1
# operation id: 202
# operation id: 202 WriteRead#: True data_id: 175 tier: DRAM
# [203.63181022272443] Wrote #175 16MB to Tier 1
# operation id: 203
# operation id: 203 WriteRead#: False data_id: 267 tier: Tier 0
# [204.5926859608969] Read #267 11MB from Tier 0
# operation id: 204
# operation id: 204 WriteRead#: True data_id: 623 tier: DRAM
# [205.45710977066338] Wrote #623 3MB to Tier 1
# operation id: 205
# operation id: 205 WriteRead#: True data_id: 897 tier: DRAM
# [205.72023224147628] Wrote #897 13MB to Tier 1
# operation id: 206
# operation id: 206 WriteRead#: False data_id: 531 tier: Tier 0
# [206.53709274722465] Read #531 10MB from Tier 0
# operation id: 207
# operation id: 207 WriteRead#: False data_id: 810 tier: Tier 1
# [208.03369961794178] Read #810 1MB from Tier 1
# operation id: 208
# operation id: 208 WriteRead#: False data_id: 742 tier: Tier 0
# [209.0698948595465] Read #742 5MB from Tier 0
# operation id: 209
# operation id: 209 WriteRead#: False data_id: 729 tier: Tier 1
# [210.9625707492554] Read #729 1MB from Tier 1
# operation id: 210
# operation id: 210 WriteRead#: True data_id: 969 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 738/1000 (73.80%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [211.27420943079292] Wrote #969 12MB to Tier 1
# operation id: 211
# operation id: 211 WriteRead#: False data_id: 99 tier: DRAM
# [212.81018974859103] Read #99 1MB from DRAM
# operation id: 212
# operation id: 212 WriteRead#: True data_id: 43 tier: DRAM
# [213.65776399153083] Wrote #43 10MB to Tier 1
# operation id: 213
# operation id: 213 WriteRead#: False data_id: 259 tier: Tier 0
# [214.98255252093784] Read #259 6MB from Tier 0
# operation id: 214
# operation id: 214 WriteRead#: False data_id: 439 tier: Tier 1
# [215.64611558193124] Read #439 9MB from Tier 1
# operation id: 215
# operation id: 215 WriteRead#: True data_id: 979 tier: DRAM
# [216.84206570420034] Wrote #979 5MB to Tier 1
# operation id: 216
# operation id: 216 WriteRead#: False data_id: 314 tier: Tier 1
# [217.31596803379662] Read #314 1MB from Tier 1
# operation id: 217
# operation id: 217 WriteRead#: True data_id: 250 tier: DRAM
# [218.74770319246858] Wrote #250 16MB to Tier 1
# operation id: 218
# operation id: 218 WriteRead#: False data_id: 43 tier: Tier 1
# [219.25671485047076] Read #43 2MB from Tier 1
# operation id: 219
# operation id: 219 WriteRead#: True data_id: 771 tier: DRAM
# [220.50039720872903] Wrote #771 11MB to Tier 1
# operation id: 220
# operation id: 220 WriteRead#: True data_id: 282 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 792/1000 (79.20%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [220.81191488842157] Wrote #282 8MB to Tier 1
# operation id: 221
# operation id: 221 WriteRead#: True data_id: 370 tier: DRAM
# [221.9433845833518] Wrote #370 15MB to Tier 1
# operation id: 222
# operation id: 222 WriteRead#: False data_id: 328 tier: Tier 1
# [222.53870048319436] Read #328 1MB from Tier 1
# operation id: 223
# operation id: 223 WriteRead#: True data_id: 795 tier: DRAM
# [224.3674305362964] Wrote #795 10MB to Tier 1
# operation id: 224
# operation id: 224 WriteRead#: False data_id: 20 tier: Tier 0
# [225.47359472025298] Read #20 10MB from Tier 0
# operation id: 225
# operation id: 225 WriteRead#: True data_id: 687 tier: DRAM
# [227.11293556688082] Wrote #687 3MB to Tier 1
# operation id: 226
# operation id: 226 WriteRead#: True data_id: 952 tier: DRAM
# [228.22323187365203] Wrote #952 9MB to Tier 1
# operation id: 227
# operation id: 227 WriteRead#: False data_id: 8 tier: Tier 1
# [229.09933327767706] Read #8 2MB from Tier 1
# operation id: 228
# operation id: 228 WriteRead#: True data_id: 355 tier: DRAM
# [229.72601641388292] Wrote #355 9MB to Tier 1
# operation id: 229
# operation id: 229 WriteRead#: True data_id: 180 tier: DRAM
# [231.27004144644437] Wrote #180 19MB to Tier 1
# operation id: 230
# operation id: 230 WriteRead#: False data_id: 842 tier: Tier 0
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 865/1000 (86.50%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [232.08868313912768] Read #842 11MB from Tier 0
# operation id: 231
# operation id: 231 WriteRead#: False data_id: 375 tier: Tier 1
# [232.54141843517007] Read #375 2MB from Tier 1
# operation id: 232
# operation id: 232 WriteRead#: False data_id: 314 tier: Tier 1
# [233.95625473187354] Read #314 3MB from Tier 1
# operation id: 233
# operation id: 233 WriteRead#: False data_id: 687 tier: Tier 1
# [234.4161760606025] Read #687 2MB from Tier 1
# operation id: 234
# operation id: 234 WriteRead#: False data_id: 672 tier: DRAM
# [236.26278805703285] Read #672 1MB from DRAM
# operation id: 235
# operation id: 235 WriteRead#: True data_id: 987 tier: DRAM
# [237.05268513437468] Wrote #987 19MB to Tier 1
# operation id: 236
# operation id: 236 WriteRead#: True data_id: 760 tier: DRAM
# [237.28217873332883] Wrote #760 4MB to Tier 1
# operation id: 237
# operation id: 237 WriteRead#: True data_id: 297 tier: DRAM
# [238.88465744864382] Wrote #297 4MB to Tier 1
# operation id: 238
# operation id: 238 WriteRead#: False data_id: 573 tier: Tier 1
# [240.06345139357066] Read #573 1MB from Tier 1
# operation id: 239
# operation id: 239 WriteRead#: False data_id: 193 tier: Tier 1
# [240.80655803281613] Read #193 1MB from Tier 1
# operation id: 240
# operation id: 240 WriteRead#: False data_id: 760 tier: Tier 1
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 892/1000 (89.20%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [241.5237936713182] Read #760 3MB from Tier 1
# operation id: 241
# operation id: 241 WriteRead#: True data_id: 704 tier: DRAM
# [243.17185028581312] Wrote #704 2MB to Tier 1
# operation id: 242
# operation id: 242 WriteRead#: False data_id: 308 tier: Tier 1
# [244.03626703242887] Read #308 10MB from Tier 1
# operation id: 243
# operation id: 243 WriteRead#: True data_id: 425 tier: DRAM
# [245.8038123396375] Wrote #425 16MB to Tier 1
# operation id: 244
# operation id: 244 WriteRead#: False data_id: 360 tier: Tier 1
# [246.17098706628235] Read #360 2MB from Tier 1
# operation id: 245
# operation id: 245 WriteRead#: True data_id: 423 tier: DRAM
# [246.88194537964412] Wrote #423 1MB to Tier 1
# operation id: 246
# operation id: 246 WriteRead#: True data_id: 255 tier: DRAM
# [247.58929995844] Wrote #255 7MB to Tier 1
# operation id: 247
# operation id: 247 WriteRead#: True data_id: 616 tier: DRAM
# [248.6454270447022] Wrote #616 15MB to Tier 1
# operation id: 248
# operation id: 248 WriteRead#: False data_id: 194 tier: Tier 1
# [248.95088747083642] Read #194 5MB from Tier 1
# operation id: 249
# operation id: 249 WriteRead#: True data_id: 958 tier: DRAM
# [249.7917806869296] Wrote #958 1MB to Tier 1
# operation id: 250
# operation id: 250 WriteRead#: True data_id: 754 tier: DRAM
#
# --- Tier Utilization ---
# DRAM: 94/100 (94.00%)
# Tier 0: 251/300 (83.67%)
# Tier 1: 934/1000 (93.40%)
# Tier 2: 0/10000 (0.00%)
# Tier 3: 0/5000000 (0.00%)
# ------------------------
#
# [250.837575907344] Wrote #754 16MB to Tier 1
# operation id: 251
# operation id: 251 WriteRead#: False data_id: 903 tier: Tier 1
# [252.6926193212759] Read #903 4MB from Tier 1
# operation id: 252
# operation id: 252 WriteRead#: True data_id: 224 tier: DRAM
# [253.41800021266985] Wrote #224 17MB to Tier 1
# operation id: 253
# operation id: 253 WriteRead#: False data_id: 771 tier: Tier 1
# [255.32475122769912] Read #771 3MB from Tier 1
# operation id: 254
# operation id: 254 WriteRead#: False data_id: 881 tier: Tier 1
# [255.52331509923968] Read #881 2MB from Tier 1
# operation id: 255
# operation id: 255 WriteRead#: True data_id: 747 tier: DRAM
# [255.87153464719196] Wrote #747 14MB to Tier 1
# operation id: 256
# operation id: 256 WriteRead#: True data_id: 214 tier: DRAM
# [256.18021638638817] Tier 1 full, triggering migration
# [256.18021638638817] Evicted #None 9MB from Tier 1. Total evicted: 9MB
# [256.18021638638817] Evicted #None 8MB from Tier 1. Total evicted: 17MB
# [256.18021638638817] Data blocks in Tier 1: {375: (6, 1741289436.6191614), 899: (19, 1741289436.6171973), 810: (1, 1741289436.6179566), 848: (19, 1741289436.613582), 231: (1, 1741289436.6172245), 324: (12, 1741289436.6172504), 204: (17, 1741289436.612864), 881: (6, 1741289436.6199322), 274: (6, 1741289436.614069), 333: (3, 1741289436.616435), 606: (2, 1741289436.6173944), 86: (19, 1741289436.61613), 453: (9, 1741289436.613489), 439: (19, 1741289436.6181686), 110: (11, 1741289436.6175785), 633: (16, 1741289436.6163137), 497: (2, 1741289436.6176374), 991: (2, 1741289436.6139743), 715: (2, 1741289436.6140273), 280: (20, 1741289436.6155374), 364: (15, 1741289436.6143713), 94: (9, 1741289436.6157062), 239: (9, 1741289436.6145766), 284: (13, 1741289436.6172953), 573: (14, 1741289436.6194296), 360: (3, 1741289436.6196387), 314: (8, 1741289436.6191876), 592: (3, 1741289436.6156797), 193: (7, 1741289436.6194634), 308: (18, 1741289436.619574), 513: (6